# %% [markdown]
# ## README ##
# Here we present a solution to detect anomalies on Data Centers networks, using the Grey Wolf Optimizer (GWO) [1] to select features and Machine Learning (ML) algorithms to create models that use less features as possible and reach considerable accuracy. We compare results with a solution without features selection.
#
# This code is the implementation of the solution reported at the paper "Detecção Eficiente de Anomalias em Redes de Data Centers Apoiada por Aprendizado de Máquina e Otimizador do Lobo Cinzento para Seleção de Atributos" published at SBRC 2023.
#
# #Features#
#  - Creates detection models  using ML algorithms with less features as possible, with features selection;
#  - Reduces the number of features to generate models without a significant impact on model accuracy, using GWO.
#  - Improve the utilization of the network resources because fewer data need to be transferred to be classified
#  - Improve the utilization of the processing resources because fewer
# features need to be analyzed
# .
#
# #How to run#
#
#
# To run this code, first you must download the following datasets:
#
# *   **KDDCup99**:  file 'kddcup.data_10_percent.gz', following this link: 'https://kdd.ics.uci.edu/databases/kddcup99/kddcup99.html'. This file contents 10% of total flows from the entire dataset and we use that to run our experiments.
# * **UNSW-NB15**:  file 'UNSW_NB15_training-set.csv', following this link: 'https://research.unsw.edu.au/projects/unsw-nb15-dataset' . Containing 175,341 records in total.
#
# Save then on your Google Drive, after that, you need to set it on the proper place, signalized as '#Load the data" in the functions 'load_KDD99()' and 'load_UNSW_NB15()', respectively.
#
#
#
# After to set the dataset, this code runs an experiment without feature selection, the Gray Wolf Optimizer (GWO), as a comparing reference. Followed by an experiment using GWO to select features and the accuracy to compose the fitness function. And at the end, the experiment using GWO to select features and the F1-Score as parameter of the GWO fitness function.
#
# <br>
#
# #Contact#
#
# Henrique Salvador (PhD Student)
#
# e-mail: henriquesalvador@ime.usp.br
#
#
# <br>
#
# #Reference#
# [1] Seyedali Mirjalili, Seyed Mohammad Mirjalili, Andrew Lewis. Grey Wolf Optimizer. **Advances in Engineering Software**. Volume 69, 2014, Pages 46-61, ISSN 0965-9978.(https://doi.org/10.1016/j.advengsoft.2013.12.007)

# %%
import random
import numpy
import math
import time

import numpy as np
import pandas as pd

from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score


from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def GWO(objf,lb,ub,dim,SearchAgents_no,Max_iter):

    # The wolves alpha, beta, and delta_pos are initialized
    Alpha_pos=numpy.zeros(dim)
    Alpha_score=float("inf")

    Beta_pos=numpy.zeros(dim)
    Beta_score=float("inf")

    Delta_pos=numpy.zeros(dim)
    Delta_score=float("inf")

    if not isinstance(lb, list):
        lb = [lb] * dim
    if not isinstance(ub, list):
        ub = [ub] * dim

    #Initialize the positions of search agents
    Positions = numpy.zeros((SearchAgents_no, dim))
    for i in range(dim):
        Positions[:, i] = numpy.random.uniform(0,1, SearchAgents_no) * (ub[i] - lb[i]) + lb[i]     # => RANDOM UNIFORM
    Convergence_curve=numpy.zeros(Max_iter)

     # Loop counter
    print("GWO is optimizing  \""+objf.__name__+"\"")

    timerStart=time.time()
    # Main loop
    for l in range(0,Max_iter):
        for i in range(0,SearchAgents_no):

            # Return back the search agents that go beyond the boundaries of the search space
            for j in range(dim):
                Positions[i,j]=numpy.clip(Positions[i,j], lb[j], ub[j])

            # Calculate objective function for each search agent
            fitness=objf(Positions[i,:])

            # Update Alpha, Beta and Delta wolves
            if fitness<Alpha_score :
                Alpha_score=fitness; # Update alpha
                Alpha_pos=Positions[i,:].copy()


            if (fitness>Alpha_score and fitness<Beta_score ):
                Beta_score=fitness  # Update beta
                Beta_pos=Positions[i,:].copy()


            if (fitness>Alpha_score and fitness>Beta_score and fitness<Delta_score):
                Delta_score=fitness # Update delta
                Delta_pos=Positions[i,:].copy()




        a=2-l*((2)/Max_iter); # a decreases linearly from 2 to 0

        # Update the Position of search agents including omegas
        for i in range(0,SearchAgents_no):  # number of wolves (agents)
            for j in range (0,dim):         #dim = n_features

                r1=random.random() # r1 is a random number in [0,1]
                r2=random.random() # r2 is a random number in [0,1]

                A1=2*a*r1-a; # Equation (3.3)
                C1=2*r2; # Equation (3.4)

                D_alpha=abs(C1*Alpha_pos[j]-Positions[i,j]); # Equation (3.5)-part 1
                X1=Alpha_pos[j]-A1*D_alpha; # Equation (3.6)-part 1

                r1=random.random()
                r2=random.random()

                A2=2*a*r1-a; # Equation (3.3)
                C2=2*r2; # Equation (3.4)

                D_beta=abs(C2*Beta_pos[j]-Positions[i,j]); # Equation (3.5)-part 2
                X2=Beta_pos[j]-A2*D_beta; # Equation (3.6)-part 2

                r1=random.random()
                r2=random.random()

                A3=2*a*r1-a; # Equation (3.3)
                C3=2*r2; # Equation (3.4)

                D_delta=abs(C3*Delta_pos[j]-Positions[i,j]); # Equation (3.5)-part 3
                X3=Delta_pos[j]-A3*D_delta; # Equation (3.5)-part 3

                Positions[i,j]=(X1+X2+X3)/3  # Equation (3.7)




        Convergence_curve[l]=Alpha_score;

        #if (l%1==0):
               #print(['At iteration '+ str(l)+ ' the best fitness is '+ str(Alpha_score)]);
              # print('alpha:', numpy.where(Alpha_pos>0.5)[0])

    timerEnd=time.time()
    print('Completed in', (timerEnd - timerStart))


    return Alpha_pos

# %%
num_features = -1


def fitness_function_accur(positions):
    features = np.where(positions>=0.4999)[0] # Here we consider selected features just ones with random number greater or equals than 0.5
    print('selected_features (partial):', features)
    train_xf = train_x.iloc[:, features]
    test_xf = test_x.iloc[:, features]

    knn_classifier = KNeighborsClassifier(n_neighbors=7)
    knn_classifier.fit(train_xf, train_y)
    accuracy = knn_classifier.score(test_xf, test_y)
    print('Accuracy (partial):', accuracy)
    print("------------ ")
    w = 0.9
    return -(w*accuracy + (1-w) * 1/(len(features)))


def fitness_function_f1(positions):
    features = np.where(positions>=0.4999)[0] # Here we consider selected features just ones with random number greater or equals than 0.5
    print('selected_features (partial):', features)
    train_xf = train_x.iloc[:, features]
    test_xf = test_x.iloc[:, features]
    knn_classifier = KNeighborsClassifier(n_neighbors=7)
    knn_classifier.fit(train_xf, train_y)
    result = knn_classifier.predict(test_xf)
    f1 = f1_score(test_y, result, average='weighted')
    print("F1-Score (partial): ", f1)
    print("------------ ")
    y = 0.9
    return -(y*f1 + (1-y)* 1/(len(features)))

def load_KDD99():
    print("########### Loading KDD Cup 99 dataset ##############")
    # Load the data
    #when using KDD99 dataset, the number of features is 41
    n_features = 41
    #Here you must to set your Google Drive folder where the dataset was save.
    df_full = pd.read_csv("/content/drive/MyDrive/04_experimentos/01_gwo/kddcup.data_10_percent_corrected", header=None)
    df = df_full.sample(frac=.05, replace=True, random_state=1)
    print(df.shape)

    #Transforming data
    # Categorize columns: "protocols", "services", "flags", "attacks"
    df[1], protocols= pd.factorize(df[1])
    df[2], services = pd.factorize(df[2])
    df[3], flags    = pd.factorize(df[3])
    df[41], attacks = pd.factorize(df[41])

    #Split the dataset on train_data (75%) and test_data (25%)
    train_data, test_data = train_test_split(df)

    return n_features, train_data.iloc[:, :num_features], test_data.iloc[:, :num_features], train_data.iloc[:, -1], test_data.iloc[:, -1]


def load_UNSW_NB15():
    print("########### Loading UNSW-NB15 dataset ##############")
    # Load the data
    n_features = 58
    df_full = pd.read_csv('/content/drive/MyDrive/05_UNSW_NB15/datasets/UNSW_NB15.csv')
    #df = df_full
    df = df_full.sample(frac=0.2, replace=True, random_state=1)

    df['service'].replace('-',np.nan,inplace=True)
    df.dropna(inplace=True)

    features = pd.read_csv('/content/drive/MyDrive/05_UNSW_NB15/datasets/UNSW_NB15_features.csv')
    # selecting column names of all data types
    nominal_names = features['Name'][features['Type ']=='nominal']
    integer_names = features['Name'][features['Type ']=='integer']
    binary_names = features['Name'][features['Type ']=='binary']
    float_names = features['Name'][features['Type ']=='float']

    # selecting common column names from dataset and feature dataset
    cols = df.columns
    nominal_names = cols.intersection(nominal_names)
    integer_names = cols.intersection(integer_names)
    binary_names = cols.intersection(binary_names)
    float_names = cols.intersection(float_names)

    # Converting integer columns to numeric
    for c in integer_names:
      pd.to_numeric(df[c])

      # Converting binary columns to numeric
    for c in binary_names:
      pd.to_numeric(df[c])

      # Converting float columns to numeric
    for c in float_names:
      pd.to_numeric(df[c])

    num_col = df.select_dtypes(include='number').columns

    # selecting categorical data attributes
    cat_col = df.columns.difference(num_col)
    cat_col = cat_col[1:]
    cat_col

    # creating a DF with only categorical attributes
    data_cat = df[cat_col].copy()
    data_cat.head()
    df.shape

    ### Convert categorical attributes to binary ones, named as "column_value"
    data_cat = pd.get_dummies(data_cat,columns=cat_col)
    df = pd.concat([df, data_cat],axis=1)
    df.drop(columns=cat_col,inplace=True)


    ## Data Normalization
    # selecting numeric attributes columns from data
    num_col = list(df.select_dtypes(include='number').columns)
    num_col.remove('id')
    num_col.remove('label')
    print(num_col)

    # Normalizing data
    minmax_scale = MinMaxScaler(feature_range=(0, 1))
    def normalization(df,col):
      for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = minmax_scale.fit_transform(arr.reshape(len(arr),1))
      return df

    df = normalization(df.copy(),num_col)
    X = df.drop(columns=['label','attack_cat','id'],axis=1)
    Y = df['label']
    X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.25, random_state=1)

    return n_features,  X_train,X_test,y_train,y_test



#To run experiments with KDD Cup 99 dataset, uncomment the line below and comment the next one: 'num_features, train_x, test_x, train_y, test_y = load_UNSW_NB15()' .
#num_features, train_x, test_x, train_y, test_y = load_KDD99()

#To run experiments with UNSW_NB15 dataset, uncomment the line below and comment the previous one: 'num_features, train_x, test_x, train_y, test_y = load_KDD99()'.
num_features, train_x, test_x, train_y, test_y = load_UNSW_NB15()


print ('train_x shape:', train_x.shape)
print ('train_y shape:', train_y.shape)
print ('test_x shape:', test_x.shape)
print ('test_y shape:', test_y.shape)

print ('############ Begin  ############ Result withou GWO:')
timerStart=time.time()
knn_classifier = KNeighborsClassifier(n_neighbors=7)
knn_classifier.fit(train_x, train_y)
accuracy = knn_classifier.score(test_x, test_y)

knn_classifier = KNeighborsClassifier(n_neighbors=7)
knn_classifier.fit(train_x, train_y)

predicted = knn_classifier.predict(test_x)
print('accuracy_score (final):',accuracy_score(test_y, predicted))

knn_classifier = KNeighborsClassifier(n_neighbors=7)
knn_classifier.fit(train_x, train_y)
accuracy = knn_classifier.score(test_x, test_y)
timerEnd=time.time()
print('Completed in', (timerEnd - timerStart))

######### end  ############ Result withou GWO

# Feature selection using GWO+F1 Score
print ('\n############ Begin  ############ Result GWO with F1-Score implementation:')
fit = GWO(fitness_function_f1, 0, 1, num_features, 10, 20)

selected_features = np.where(fit>0.5)[0]
print('selected_features (final):',len(selected_features), selected_features)
train_xf = train_x.iloc[:, selected_features]
test_xf = test_x.iloc[:, selected_features]
knn_classifier = KNeighborsClassifier(n_neighbors=7)
knn_classifier.fit(train_xf, train_y)

predicted = knn_classifier.predict(test_xf)
print('accuracy_score (final):',accuracy_score(test_y, predicted))

############ end  ############ Result F1 GWO:')

# Feature selection using GWO+F1 Score
print ('\n############ Begin  ############ Result GWO with Accuracy implementation:')

knn_classifier = KNeighborsClassifier(n_neighbors=7)
knn_classifier.fit(train_x, train_y)
accuracy = knn_classifier.score(test_x, test_y)

fit = GWO(fitness_function_accur, 0, 1, num_features, 10, 20)
selected_features = np.where(fit>0.5)[0]
print('selected_features (final):',len(selected_features), selected_features)


train_xf = train_x.iloc[:, selected_features]
test_xf = test_x.iloc[:, selected_features]

knn_classifier = KNeighborsClassifier(n_neighbors=7)
knn_classifier.fit(train_xf, train_y)
predicted = knn_classifier.predict(test_xf)
#print('confusion_matrix:\n',confusion_matrix(test_y, predicted))
print('accuracy_score (final):',accuracy_score(test_y, predicted))
# Out:
# ########### Loading UNSW-NB15 dataset ##############
# ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports', 'proto_tcp', 'proto_udp', 'service_dhcp', 'service_dns', 'service_ftp', 'service_ftp-data', 'service_http', 'service_irc', 'service_pop3', 'service_radius', 'service_smtp', 'service_snmp', 'service_ssh', 'service_ssl', 'state_CON', 'state_FIN', 'state_INT', 'state_REQ', 'state_RST']
# train_x shape: (12195, 58)
# train_y shape: (12195,)
# test_x shape: (4065, 58)
# test_y shape: (4065,)
# ############ Begin  ############ Result withou GWO:
# accuracy_score (final): 0.984009840098401
# Completed in 4.951750993728638
#
# ############ Begin  ############ Result GWO with F1-Score implementation:
# GWO is optimizing  "fitness_function_f1"
# selected_features (partial): [ 6  7  8  9 15 16 17 19 21 27 28 30 31 32 36 39 40 42 43 44 46 47 48 49
#  50 52 55 57]
# F1-Score (partial):  0.9802334144993895
# ------------
# selected_features (partial): [ 0  4  6  7  9 10 11 12 14 15 16 17 19 21 22 25 26 27 28 34 36 37 38 39
#  40 44 46 48 49 51 52 54 56]
# F1-Score (partial):  0.9811723543522932
# ------------
# selected_features (partial): [ 1  5 10 12 13 14 17 20 22 24 28 30 32 37 38 39 44 45 47 48 51 52 53 54
#  56 57]
# F1-Score (partial):  0.9819596381629282
# ------------
# selected_features (partial): [ 4  5 10 11 12 14 15 16 18 19 21 22 26 29 32 35 38 40 42 43 47 48 49 51
#  52 53 54 55 56]
# F1-Score (partial):  0.9796549578393074
# ------------
# selected_features (partial): [ 0  2  5  6  8  9 12 13 14 16 18 22 24 25 28 30 31 32 34 36 38 39 40 41
#  43 46 52 53 55]
# F1-Score (partial):  0.9780461594967982
# ------------
# selected_features (partial): [ 0  1  2  3  5  7  8  9 11 12 13 14 15 18 19 20 21 24 25 29 31 33 34 36
#  37 38 39 42 43 44 45 46 47 48 49 51 52 54 56]
# F1-Score (partial):  0.9797467631380847
# ------------
# selected_features (partial): [ 0  3  5 12 16 17 18 21 23 24 26 27 29 34 35 36 39 40 41 43 44 45 47 51
#  54 56]
# F1-Score (partial):  0.9617053768986736
# ------------
# selected_features (partial): [ 0  1  4  5  6  9 10 14 15 17 22 24 26 28 29 30 33 35 39 40 41 43 46 47
#  50 51 52 55 56]
# F1-Score (partial):  0.981437622002783
# ------------
# selected_features (partial): [ 2  3  8  9 10 11 13 16 18 19 20 25 26 29 30 32 33 35 36 38 40 41 43 44
#  45 46 47 48 51 52 54 57]
# F1-Score (partial):  0.9770594700359801
# ------------
# selected_features (partial): [ 0  2  3  5  6  7 10 12 14 15 16 18 21 22 26 29 32 34 35 37 40 41 42 44
#  47 50 52 53 56 57]
# F1-Score (partial):  0.9814094961719922
# ------------
# selected_features (partial): [ 1  2  4  5  6 10 14 15 16 17 18 21 22 23 26 28 30 36 38 39 45 47 49 50
#  52]
# F1-Score (partial):  0.9811436194608217
# ------------
# selected_features (partial): [ 0  3  4  5  6  9 10 11 14 16 17 18 22 23 24 26 29 30 31 32 36 38 39 41
#  42 43 47 48 50 51 52 54 57]
# F1-Score (partial):  0.9794959731152405
# ------------
# selected_features (partial): [ 0  2  4  5  6  7  9 10 13 15 17 22 24 26 28 29 34 37 39 40 42 43 45 47
#  50 52 56 57]
# F1-Score (partial):  0.9819663378001514
# ------------
# selected_features (partial): [ 0  1  2  3  4  5  6  7  9 10 12 13 14 15 17 18 22 26 29 32 37 38 40 42
#  46 47 48 49 50 54 57]
# F1-Score (partial):  0.9830694113084055
# ------------
# selected_features (partial): [ 0  2  3  4  5  6  8 14 15 24 25 26 28 29 30 31 33 34 35 37 38 39 40 44
#  47 51 52]
# F1-Score (partial):  0.9842501871171236
# ------------
# selected_features (partial): [ 0  1  4  5  6  7 10 12 13 14 15 20 22 24 26 28 29 33 35 37 38 39 40 42
#  46 47 50 51 52 55 56]
# F1-Score (partial):  0.9837226055868579
# ------------
# selected_features (partial): [ 2  3  4  5  6 10 12 14 17 18 21 22 23 26 28 29 34 35 37 38 39 40 46 47
#  48 50 51 52 54 56]
# F1-Score (partial):  0.9816186146840693
# ------------
# selected_features (partial): [ 1  2  3  4  5  6 10 14 15 22 26 32 34 35 36 37 39 45 46 50 51 52 53 55
#  56]
# F1-Score (partial):  0.9822622469387651
# ------------
# selected_features (partial): [ 0  1  2  4  6  7  9 14 15 17 20 24 26 28 29 32 33 35 36 37 38 39 40 41
#  44 46 47 48 50 51 52 56 57]
# F1-Score (partial):  0.9831921513158894
# ------------
# selected_features (partial): [ 1  4  5  7 15 17 21 22 24 26 30 31 32 35 38 39 40 41 43 44 47 53 56 57]
# F1-Score (partial):  0.9828771062728113
# ------------
# selected_features (partial): [ 3  5  6  7  8 10 12 14 15 21 22 24 26 28 32 34 35 36 37 38 39 40 41 46
#  51 52 53 56 57]
# F1-Score (partial):  0.9819863051838013
# ------------
# selected_features (partial): [ 1  3  4  5  8 10 14 15 16 18 21 22 23 24 26 29 32 35 39 40 41 46 47 52
#  57]
# F1-Score (partial):  0.9760551796050168
# ------------
# selected_features (partial): [ 1  5  7 15 17 20 24 26 29 30 32 37 38 39 40 41 48 56]
# F1-Score (partial):  0.981709105843762
# ------------
# selected_features (partial): [ 1  2  3  4  5  6 10 12 15 20 22 24 26 30 32 35 36 37 39 40 44 46 47 51
#  52 54 57]
# F1-Score (partial):  0.9827360968345464
# ------------
# selected_features (partial): [ 0  1  3  4  5  6  7 10 14 15 17 24 26 29 32 33 34 36 38 39 40 41 44 45
#  47 50 51 53 56]
# F1-Score (partial):  0.9800268510969464
# ------------
# selected_features (partial): [ 1  2  3  4  5  6  7 14 17 22 24 26 28 31 33 34 35 37 39 41 45 47 51 57]
# F1-Score (partial):  0.9824342176282939
# ------------
# selected_features (partial): [ 0  1  4  5  6  7 10 14 21 22 24 26 29 30 34 35 37 38 40 41 44 47 53 56]
# F1-Score (partial):  0.9834607941601663
# ------------
# selected_features (partial): [ 1  2  4  5  6  7 10 14 15 17 21 22 24 31 37 40 41 44 45 46 51 52 56 57]
# F1-Score (partial):  0.9814722648631692
# ------------
# selected_features (partial): [ 1  3  4  7  9 10 17 20 21 24 26 29 30 31 32 34 35 36 37 39 40 41 47 52
#  53 54 56]
# F1-Score (partial):  0.9829032372099487
# ------------
# selected_features (partial): [ 1  2  3  4  6  7  9 14 15 17 21 22 26 29 30 32 34 35 36 37 39 40 44 45
#  46 47 50 51 52 56]
# F1-Score (partial):  0.9816816713649433
# ------------
# selected_features (partial): [ 0  2  4  5  6  7  8 12 14 24 25 26 28 34 35 37 38 39 40 46 51 57]
# F1-Score (partial):  0.9835148773518922
# ------------
# selected_features (partial): [ 1  3  4  5  6  8 10 14 15 17 22 24 26 29 30 31 32 33 34 35 37 39 40 44
#  47 51]
# F1-Score (partial):  0.9829226122425604
# ------------
# selected_features (partial): [ 0  2  4  5  6  7  8 14 15 17 21 22 24 25 26 29 30 31 34 35 37 38 40 41
#  47 57]
# F1-Score (partial):  0.981674756376051
# ------------
# selected_features (partial): [ 2  3  5  6  8 10 12 14 15 17 21 23 24 26 30 35 37 38 39 40 41 44 46 51]
# F1-Score (partial):  0.9822232454643879
# ------------
# selected_features (partial): [ 0  1  2  4  5  6  7 14 21 22 24 26 28 29 32 33 34 35 39 40 41 44 47 51
#  56 57]
# F1-Score (partial):  0.9832170326588393
# ------------
# selected_features (partial): [ 1  2  3  4  5  6 22 24 26 28 29 30 31 33 34 35 37 40 41 51]
# F1-Score (partial):  0.986188877467637
# ------------
# selected_features (partial): [ 1  3  5  6 14 21 24 26 30 33 34 35 37 38 39 40 44 45 46 47 51 53]
# F1-Score (partial):  0.9837403930272013
# ------------
# selected_features (partial): [ 1  2  3  4  5  6  8 14 15 21 22 24 26 29 30 33 34 37 39 41 44 45 47 56]
# F1-Score (partial):  0.9805342092583316
# ------------
# selected_features (partial): [ 2  3  4  6  7 14 15 22 24 26 29 30 31 33 34 35 37 38 39 41 44 46 51 52
#  54 56]
# F1-Score (partial):  0.9847202722823031
# ------------
# selected_features (partial): [ 2  3  4  5  6  7 15 17 21 22 24 26 28 30 32 33 35 37 40 41 47 51 57]
# F1-Score (partial):  0.9839004577681812
# ------------
# selected_features (partial): [ 2  3  4  6  7 12 15 24 26 30 31 32 33 34 35 37 41 51 53 55 57]
# F1-Score (partial):  0.9849911569920213
# ------------
# selected_features (partial): [ 1  2  4  5  6  7 10 14 15 21 22 24 26 28 29 31 33 35 40 41 47 56 57]
# F1-Score (partial):  0.9790405227560551
# ------------
# selected_features (partial): [ 2  3  4  5  6  7  8 14 15 21 22 24 26 28 30 31 32 34 35 37 40 47 51 52]
# F1-Score (partial):  0.9847035077642006
# ------------
# selected_features (partial): [ 3  4  5  6 14 15 21 22 24 25 26 28 31 33 37 39 40 47 55 57]
# F1-Score (partial):  0.9817495880822347
# ------------
# selected_features (partial): [ 2  3  4  5  6 17 22 24 26 28 29 31 32 33 35 37 40 41 44 51 52 53 57]
# F1-Score (partial):  0.9829161750319579
# ------------
# selected_features (partial): [ 2  3  4  5  6  7 22 24 26 30 31 32 35 37 39 40 44 47 51 53 55 57]
# F1-Score (partial):  0.9844934875064171
# ------------
# selected_features (partial): [ 2  3  4  6  7 15 24 26 28 31 35 36 37 40 41 44 46 51 57]
# F1-Score (partial):  0.9832718327183272
# ------------
# selected_features (partial): [ 2  3  4  5 14 15 22 24 26 28 29 31 32 33 37 38 40 41 51 55 56]
# F1-Score (partial):  0.9827486945122776
# ------------
# selected_features (partial): [ 1  2  3  4  5 10 15 17 19 21 22 24 26 28 29 30 31 32 34 37 38 47 51 52
#  57]
# F1-Score (partial):  0.9816816713649433
# ------------
# selected_features (partial): [ 3  4  6  7 14 15 22 24 26 30 31 32 33 35 37 40 51 57]
# F1-Score (partial):  0.9854780279822002
# ------------
# selected_features (partial): [ 2  3  6  7 17 22 24 26 28 29 30 31 32 34 35 37 51 55 57]
# F1-Score (partial):  0.9831478157412068
# ------------
# selected_features (partial): [ 2  4  5  6  7 15 22 24 25 26 30 31 32 34 35 37 39 51 53 55 57]
# F1-Score (partial):  0.9849857577443087
# ------------
# selected_features (partial): [ 2  3  4  5  6  7 10 14 15 22 24 26 29 30 31 32 34 37 39 40 47 51]
# F1-Score (partial):  0.9844878928016029
# ------------
# selected_features (partial): [ 1  2  3  4  5  7 15 22 24 26 30 31 33 34 35 36 37 39 47 51 57]
# F1-Score (partial):  0.9829607954489968
# ------------
# selected_features (partial): [ 3  5  6  7 14 22 24 26 29 31 32 33 37 39 41 44 45]
# F1-Score (partial):  0.9852292309154976
# ------------
# selected_features (partial): [ 2  3  5  6  7 15 24 26 29 30 31 33 35 37 39 42 51 57]
# F1-Score (partial):  0.9823004847429296
# ------------
# selected_features (partial): [ 1  3  4  5  7 14 22 24 26 30 31 35 36 37 39 40 41 44 47 51 53 57]
# F1-Score (partial):  0.9829670865231562
# ------------
# selected_features (partial): [ 2  3  4  5  6 14 15 24 26 29 31 32 35 37 39 40 51 57]
# F1-Score (partial):  0.9818088315413442
# ------------
# selected_features (partial): [ 3  4  5  6 12 14 22 24 26 29 30 32 34 35 37 40 47 51 57]
# F1-Score (partial):  0.9852345504223036
# ------------
# selected_features (partial): [ 2  3  4  6  7  8 15 22 24 26 28 30 32 33 35 37 40 44 51 57]
# F1-Score (partial):  0.9859702982200917
# ------------
# selected_features (partial): [ 2  3  4  5  6  7 14 15 24 26 30 31 32 33 37 40 41 44 57]
# F1-Score (partial):  0.9837696505817713
# ------------
# selected_features (partial): [ 2  3  6  7 22 24 26 29 31 32 37 44 51]
# F1-Score (partial):  0.9837344833972904
# ------------
# selected_features (partial): [ 3  5  6  7 14 21 22 23 24 26 30 32 33 37 40 45 51 54]
# F1-Score (partial):  0.9807980001901468
# ------------
# selected_features (partial): [ 3  4  5  6  7  8 22 24 26 31 35 40 41 44 51]
# F1-Score (partial):  0.9799826122081807
# ------------
# selected_features (partial): [ 3  4  6  7  8 14 15 22 24 26 28 30 31 32 33 35 37 40 41 44 51]
# F1-Score (partial):  0.9859702982200917
# ------------
# selected_features (partial): [ 2  3  4  5  6  7 24 26 29 30 31 32 33 37 39 40 41 57]
# F1-Score (partial):  0.9837638376383764
# ------------
# selected_features (partial): [ 2  3  4  6  7 15 17 22 24 26 29 31 35 40 41 44 51]
# F1-Score (partial):  0.9824276154959678
# ------------
# selected_features (partial): [ 2  3  4  6 14 24 26 30 31 32 33 35 37 44 51 53 57]
# F1-Score (partial):  0.9835384036867207
# ------------
# selected_features (partial): [ 2  3  4  5  6 14 15 17 22 24 26 29 30 31 32 33 35 37 39 40 44 51 57]
# F1-Score (partial):  0.9829226122425604
# ------------
# selected_features (partial): [ 2  3  6  7 15 22 24 26 30 32 33 35 37 39 40 44 51]
# F1-Score (partial):  0.9859652363443074
# ------------
# selected_features (partial): [ 3  4  6  7  8 17 24 26 30 31 32 35 37 39 40 44 47 51 57]
# F1-Score (partial):  0.9819995077787295
# ------------
# selected_features (partial): [ 2  3  4  6  7  8 14 22 24 28 29 30 31 32 33 35 37 39 40 44 51]
# F1-Score (partial):  0.9859652363443074
# ------------
# selected_features (partial): [ 2  4  5  6  7  8 15 19 22 24 26 30 32 37 40 51]
# F1-Score (partial):  0.9832476776643893
# ------------
# selected_features (partial): [ 3  5  6  7  8 14 15 17 20 21 22 24 26 30 32 33 35 37 39 40 44 51 57]
# F1-Score (partial):  0.9836620312173818
# ------------
# selected_features (partial): [ 2  3  4  6  7 10 14 17 21 22 24 26 28 31 32 35 37 39 44 51 57]
# F1-Score (partial):  0.9836558637948563
# ------------
# selected_features (partial): [ 4  6  7  9 22 24 26 30 31 32 33 37 38 40 44 51 57]
# F1-Score (partial):  0.983497027525035
# ------------
# selected_features (partial): [ 2  3  6  7 15 22 24 26 30 31 32 33 34 35 39 40 41 44 51 57]
# F1-Score (partial):  0.9852023687153254
# ------------
# selected_features (partial): [ 3  4  5  6  7 15 19 24 26 31 32 33 35 37 40 44 51 53 57]
# F1-Score (partial):  0.9837754443476854
# ------------
# selected_features (partial): [ 2  3  6  7 17 26 30 32 33 35 37 44 51 53]
# F1-Score (partial):  0.9812007155606614
# ------------
# selected_features (partial): [ 2  3  4  6 10 15 22 24 26 30 31 32 33 35 37 39 41 44 51]
# F1-Score (partial):  0.9849857577443087
# ------------
# selected_features (partial): [ 2  3  6  7 15 22 24 26 31 32 33 35 37 39 40 44 51 57]
# F1-Score (partial):  0.9849911569920213
# ------------
# selected_features (partial): [ 2  3  4  5  6  7  8 14 15 22 24 26 30 32 33 35 37 40 44 51]
# F1-Score (partial):  0.9857267320748934
# ------------
# selected_features (partial): [ 2  3  4  6  7 10 15 22 24 26 30 31 32 33 35 37 44 51]
# F1-Score (partial):  0.9849857577443087
# ------------
# selected_features (partial): [ 3  4  5  6  7 15 20 22 24 26 31 32 33 35 37 40 44 51 57]
# F1-Score (partial):  0.9829733569545517
# ------------
# selected_features (partial): [ 2  3  4  6  7 22 24 26 30 32 33 35 37 39 40 44 51 57]
# F1-Score (partial):  0.9859652363443074
# ------------
# selected_features (partial): [ 2  3  4  6  8 15 22 24 26 30 32 33 35 37 44 51 57]
# F1-Score (partial):  0.9852345504223036
# ------------
# selected_features (partial): [ 2  3  4  6  7  8 15 22 24 26 30 31 32 37 39 40 44 47 51 57]
# F1-Score (partial):  0.9830044014810064
# ------------
# selected_features (partial): [ 3  4  6  7 15 22 24 26 30 32 33 35 37 40 44 57]
# F1-Score (partial):  0.985721589884981
# ------------
# selected_features (partial): [ 2  3  6  7 15 22 24 26 30 32 33 35 37 40 44 51 57]
# F1-Score (partial):  0.985721589884981
# ------------
# selected_features (partial): [ 3  4  6  7 15 17 22 24 26 30 32 33 35 40 41 44 47 51]
# F1-Score (partial):  0.982407678868208
# ------------
# selected_features (partial): [ 3  6  7 15 24 26 30 33 35 37 40 44 51 57]
# F1-Score (partial):  0.9832897407763984
# ------------
# selected_features (partial): [ 2  3  4  6 15 24 26 30 32 33 34 35 37 40 44 51 55 57]
# F1-Score (partial):  0.984272697201316
# ------------
# selected_features (partial): [ 3  4  6  7  8 10 15 22 24 26 30 33 35 37 39 40 44 51 57]
# F1-Score (partial):  0.9852023687153254
# ------------
# selected_features (partial): [ 2  3  4  6  7 15 22 24 26 30 32 34 35 37 40 44 51 57]
# F1-Score (partial):  0.985721589884981
# ------------
# selected_features (partial): [ 3  6  7 15 24 26 30 33 35 37 40 44 57]
# F1-Score (partial):  0.9832897407763984
# ------------
# selected_features (partial): [ 3  4  6  7 15 22 24 26 30 32 37 40 44 51 57]
# F1-Score (partial):  0.9832537463401408
# ------------
# selected_features (partial): [ 2  3  4  6  7  8 15 22 24 26 30 32 33 35 37 40 51 57]
# F1-Score (partial):  0.9854780279822002
# ------------
# selected_features (partial): [ 3  6  7  8 22 24 26 30 33 35 37 40 44 46 51 57]
# F1-Score (partial):  0.9849529857225245
# ------------
# selected_features (partial): [ 3  4  6  7 15 22 23 24 26 30 33 35 37 40 44 51 57]
# F1-Score (partial):  0.983479000290067
# ------------
# selected_features (partial): [ 3  4  6  7 14 22 24 26 30 32 33 34 35 37 44 57]
# F1-Score (partial):  0.9854832502053976
# ------------
# selected_features (partial): [ 2  3  4  6  7  8 15 24 26 30 32 33 34 37 44 46 51]
# F1-Score (partial):  0.982567964103351
# ------------
# selected_features (partial): [ 2  3  4  6  7 15 22 24 26 30 32 33 34 37 44 51 57]
# F1-Score (partial):  0.983259795037564
# ------------
# selected_features (partial): [ 2  3  4  6  7 22 24 26 30 32 35 37 39 40 44 51 57]
# F1-Score (partial):  0.9849857577443087
# ------------
# selected_features (partial): [ 3  4  6  7  8 22 24 26 30 32 33 34 35 37 44 46 51 57]
# F1-Score (partial):  0.985721589884981
# ------------
# selected_features (partial): [ 3  4  6  7 22 24 26 30 32 33 34 37 44 57]
# F1-Score (partial):  0.9827612094677919
# ------------
# selected_features (partial): [ 3  4  6  7  8 22 24 26 30 32 33 37 40 44 51 57]
# F1-Score (partial):  0.9827612094677919
# ------------
# selected_features (partial): [ 2  3  6  7  8 22 24 26 30 32 33 35 37 40 44 46 57]
# F1-Score (partial):  0.985721589884981
# ------------
# selected_features (partial): [ 2  3  4  6  7 22 24 26 30 32 33 37 44 46 51 57]
# F1-Score (partial):  0.9827612094677919
# ------------
# selected_features (partial): [ 3  4  6  7 15 22 26 30 32 33 37 44 47 51 57]
# F1-Score (partial):  0.9819863051838013
# ------------
# selected_features (partial): [ 3  6  7 14 22 24 26 30 32 33 35 37 40 44 46 51]
# F1-Score (partial):  0.9857267320748934
# ------------
# selected_features (partial): [ 3  4  6  7 22 24 26 30 32 33 35 37 39 40 44 46 51 57]
# F1-Score (partial):  0.9859652363443074
# ------------
# selected_features (partial): [ 3  7 26 30 32 33 37 44 47 51]
# F1-Score (partial):  0.9825181014113302
# ------------
# selected_features (partial): [ 3  4  6  7 15 24 26 30 32 33 40 44 47]
# F1-Score (partial):  0.982313063153961
# ------------
# selected_features (partial): [ 2  3  4  6  7  8 22 24 26 30 32 33 37 40 44 46]
# F1-Score (partial):  0.9827612094677919
# ------------
# selected_features (partial): [ 3  6  7  8 14 15 22 24 26 30 32 33 35 37 44 46 51]
# F1-Score (partial):  0.985239852398524
# ------------
# selected_features (partial): [ 3  6  7 14 22 24 26 30 32 33 35 37 44 46]
# F1-Score (partial):  0.9854832502053976
# ------------
# selected_features (partial): [ 3  6  7  8 24 26 30 32 33 35 37 40 44 57]
# F1-Score (partial):  0.9837754443476854
# ------------
# selected_features (partial): [ 3  4  6  7  8 14 22 24 26 30 32 33 35 37 40 44 46 51]
# F1-Score (partial):  0.9854832502053976
# ------------
# selected_features (partial): [ 3  6  7 22 24 26 30 32 33 34 37 51]
# F1-Score (partial):  0.9825117754369775
# ------------
# selected_features (partial): [ 3  4  6  7  8 24 26 30 32 33 37 40 44 57]
# F1-Score (partial):  0.9818153061390216
# ------------
# selected_features (partial): [ 3  4  7 14 22 24 26 30 32 33 37 40 44 46 51]
# F1-Score (partial):  0.9817695315759529
# ------------
# selected_features (partial): [ 2  3  4  6  7 22 26 30 32 33 35 37 44 46 47 51 54 57]
# F1-Score (partial):  0.9839545017971763
# ------------
# selected_features (partial): [ 2  3  6  7  8 14 24 26 30 32 33 34 35 40 44 46 51]
# F1-Score (partial):  0.9850072481422756
# ------------
# selected_features (partial): [ 3  4  6  7 15 22 24 26 30 32 33 35 37 38 40 44 46 51 54]
# F1-Score (partial):  0.9859652363443074
# ------------
# selected_features (partial): [ 3  4  6  7  8 24 26 30 32 33 35 37 44 51 57]
# F1-Score (partial):  0.9830470127519959
# ------------
# selected_features (partial): [ 3  6  7 24 26 30 32 33 35 37 44 51]
# F1-Score (partial):  0.9835442368005674
# ------------
# selected_features (partial): [ 3  6  7 22 26 30 32 33 35 37 40 44 51]
# F1-Score (partial):  0.9842042660318489
# ------------
# selected_features (partial): [ 3  7  8 22 24 26 30 32 33 37 40 44 46 51 57]
# F1-Score (partial):  0.9815198189161377
# ------------
# selected_features (partial): [ 3  4  6  7 22 24 26 30 33 35 37 40 44 46 51 54]
# F1-Score (partial):  0.9849529857225245
# ------------
# selected_features (partial): [ 2  3  6  7 15 22 24 26 30 32 33 35 37 38 40 46]
# F1-Score (partial):  0.985721589884981
# ------------
# selected_features (partial): [ 3  4  6  7 14 22 24 26 30 32 33 35 37 44 57]
# F1-Score (partial):  0.9854832502053976
# ------------
# selected_features (partial): [ 2  3  6  7 22 24 26 32 33 34 37 44 51]
# F1-Score (partial):  0.9825181014113302
# ------------
# selected_features (partial): [ 3  6  7 14 22 24 26 30 32 33 37 44 46]
# F1-Score (partial):  0.983989653569064
# ------------
# selected_features (partial): [ 3  6  7 14 24 26 30 32 33 35 37 44]
# F1-Score (partial):  0.983053019988644
# ------------
# selected_features (partial): [ 3  6  7 24 26 30 32 33 35 37 38 44 55 57]
# F1-Score (partial):  0.9837869745577977
# ------------
# selected_features (partial): [ 3  6  7 22 24 26 30 32 33 37 44 51 54 57]
# F1-Score (partial):  0.9832476776643893
# ------------
# selected_features (partial): [ 3  4  6  7 22 24 26 30 32 33 34 37 44]
# F1-Score (partial):  0.9827612094677919
# ------------
# selected_features (partial): [ 3  6  7 24 26 30 32 33 35 37 40 54 57]
# F1-Score (partial):  0.9842670975492707
# ------------
# selected_features (partial): [ 3  6  7 14 26 30 32 33 35 37 44 47]
# F1-Score (partial):  0.9832537463401408
# ------------
# selected_features (partial): [ 3  6  7 14 24 26 30 32 33 35 37 40 44 46 47]
# F1-Score (partial):  0.9835384036867207
# ------------
# selected_features (partial): [ 3  6  7 14 26 30 32 33 35 37 44 46 51]
# F1-Score (partial):  0.9832537463401408
# ------------
# selected_features (partial): [ 3  6  7 14 26 30 32 33 35 37 40 44]
# F1-Score (partial):  0.9837403930272013
# ------------
# selected_features (partial): [ 3  6  7 14 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9835029971064666
# ------------
# selected_features (partial): [ 3  6  7 24 26 30 32 33 37 44 47]
# F1-Score (partial):  0.9815728399478219
# ------------
# selected_features (partial): [ 3  6  7 14 22 26 30 32 33 37 44]
# F1-Score (partial):  0.9824604107371335
# ------------
# selected_features (partial): [ 3  4  6  7 14 22 24 26 30 32 33 34 35 37 44]
# F1-Score (partial):  0.9854832502053976
# ------------
# selected_features (partial): [ 3  6  7 14 22 26 30 32 33 35 37 44 54]
# F1-Score (partial):  0.9839721644605126
# ------------
# selected_features (partial): [ 3  7 14 24 26 30 32 33 35 37 44 51 57]
# F1-Score (partial):  0.982313063153961
# ------------
# selected_features (partial): [ 3  4  6  7 14 22 24 26 30 32 33 34 37 44 57]
# F1-Score (partial):  0.983989653569064
# ------------
# selected_features (partial): [ 3  4  6  7 14 22 24 26 30 32 33 34 35 37 44 54]
# F1-Score (partial):  0.9857267320748934
# ------------
# selected_features (partial): [ 3  6  7 14 26 30 32 33 35 37 38 54]
# F1-Score (partial):  0.983497027525035
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 35 37 44 54]
# F1-Score (partial):  0.9823193212074095
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 35 37 44 46]
# F1-Score (partial):  0.9813502072549224
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 34 37 46]
# F1-Score (partial):  0.9847478474784748
# ------------
# selected_features (partial): [ 3  6  7 22 26 30 32 33 35 37 38 44 51]
# F1-Score (partial):  0.9834729515312974
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 35 37 44]
# F1-Score (partial):  0.9823193212074095
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 35 37 38 40 44 46 51]
# F1-Score (partial):  0.9832897407763984
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 35 44]
# F1-Score (partial):  0.9818346018621913
# ------------
# selected_features (partial): [ 3  4  6  7 22 26 30 32 33 37 44]
# F1-Score (partial):  0.9819663378001514
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 34 37 44]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 35 37]
# F1-Score (partial):  0.9823193212074095
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 46 54]
# F1-Score (partial):  0.9825306909251397
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 54]
# F1-Score (partial):  0.9825306909251397
# ------------
# selected_features (partial): [ 3  6  7  8 26 30 32 33 35 37 44 46]
# F1-Score (partial):  0.9815923640701191
# ------------
# selected_features (partial): [ 3  6  7 22 26 30 32 33 44 46]
# F1-Score (partial):  0.9824342176282939
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 35 37 40 44]
# F1-Score (partial):  0.9823193212074095
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 34 37 46]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9847478474784748
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 54]
# F1-Score (partial):  0.9825306909251397
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 35 37 44]
# F1-Score (partial):  0.9813502072549224
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44 46 54]
# F1-Score (partial):  0.9845046216691746
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 46 54]
# F1-Score (partial):  0.9825306909251397
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  6  7 22 26 30 32 33 34 37 44]
# F1-Score (partial):  0.9817159084119353
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9847478474784748
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44 54]
# F1-Score (partial):  0.9842558425584256
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 34 37 44 46]
# F1-Score (partial):  0.9847478474784748
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9822878228782288
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 34 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37]
# F1-Score (partial):  0.9842501871171236
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 34 35 37 44 46]
# F1-Score (partial):  0.9823193212074095
# ------------
# selected_features (partial): [ 3  6  7  8 26 30 32 33 37 44 46]
# F1-Score (partial):  0.9823004847429296
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 54]
# F1-Score (partial):  0.9825306909251397
# ------------
# selected_features (partial): [ 3  6  7 14 26 30 32 33 37 44]
# F1-Score (partial):  0.9835029971064666
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  4  6  7 26 30 32 33 37 44]
# F1-Score (partial):  0.9844990637786449
# ------------
# selected_features (partial): [ 3  6  7 26 30 32 33 37 44 54]
# F1-Score (partial):  0.9825306909251397
# ------------
# Completed in 180.93244552612305
# selected_features (final): 9 [ 3  4  6  7 26 30 32 33 37]
# accuracy_score (final): 0.9842558425584256
#
# ############ Begin  ############ Result GWO with Accuracy implementation:
# GWO is optimizing  "fitness_function_accur"
# selected_features (partial): [ 1  2  3  7  8  9 10 11 12 14 16 18 20 21 24 27 30 32 35 36 40 41 42 48
#  49 50 51 57]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 0  1  3  5  6  7  8 12 13 14 15 18 19 20 21 22 23 24 25 26 29 32 33 34
#  36 38 39 40 41 43 45 46 47 50 52 53 55]
# Accuracy (partial): 0.977859778597786
# ------------
# selected_features (partial): [ 2  3  4  5  7  8  9 11 13 14 15 20 22 26 29 32 34 35 36 41 42 43 44 46
#  48 52 53 55]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 1  3  4  6  7 11 13 14 15 16 18 19 20 21 22 24 25 26 27 30 32 35 36 39
#  43 44 47 48 50 53 57]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 0  1  2  3  6  7 10 12 17 21 22 23 24 26 27 31 32 33 34 36 43 47 48 53
#  54 56]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 2  3  4  7  8 13 16 17 22 23 24 26 27 28 30 31 32 33 34 35 36 37 39 43
#  45 46 47 50 52 56 57]
# Accuracy (partial): 0.9810578105781058
# ------------
# selected_features (partial): [ 0  2  3  4  5  7  8  9 17 19 20 23 24 25 29 30 31 33 35 37 39 41 42 43
#  45 51 52 54 55 56 57]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 1  5  6  7  8 11 14 15 20 22 23 25 28 29 30 32 33 34 39 40 41 43 44 46
#  47 49 55 56]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 1  3  6  8  9 11 12 13 15 17 18 19 22 26 27 28 31 32 33 34 35 40 42 43
#  44 47 48 54 56]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  1  2  3  5  6  7  9 17 18 19 20 22 23 24 25 26 30 31 34 35 37 38 39
#  45 47 49 51 52 54 56 57]
# Accuracy (partial): 0.9835178351783518
# ------------
# selected_features (partial): [ 0  1  2  3  5  6  7  9 13 17 18 22 23 26 27 28 31 32 34 35 37 39 43 46
#  47 48 52 54 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  1  3  4  6  9 12 16 17 18 20 22 23 26 27 28 30 33 39 41 45 47 49 50
#  51 52 54 56 57]
# Accuracy (partial): 0.984009840098401
# ------------
# selected_features (partial): [ 1  3  5  6  8  9 12 13 17 18 22 23 26 28 31 34 35 36 37 38 41 44 46 47
#  57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  3  6  8  9 12 17 18 19 22 23 25 26 28 33 34 35 37 39 45 46 47 50
#  51 52 54 56]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  3  6  7  9 15 16 17 19 23 25 26 27 31 33 34 36 37 40 43 45 47 48
#  52 54 56 57]
# Accuracy (partial): 0.9808118081180812
# ------------
# selected_features (partial): [ 1  3  5  6 13 16 17 18 19 20 22 28 31 34 35 37 44 46 47 50 51 54 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 1  2  4  5  6  7 11 13 16 18 19 22 24 26 27 28 29 32 34 35 37 39 42 45
#  47 52 54 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 3  5  9 18 22 23 27 28 31 32 33 34 35 37 39 42 44 45 47 49 57]
# Accuracy (partial): 0.9798277982779828
# ------------
# selected_features (partial): [ 0  1  2  3  8 13 17 18 19 24 25 26 27 31 33 34 35 37 40 43 47 49 52 54
#  56 57]
# Accuracy (partial): 0.9321033210332104
# ------------
# selected_features (partial): [ 1  2  3  4  5  7 10 12 17 18 19 22 24 26 27 30 32 34 35 38 39 44 45 47
#  48 51 54 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 0  1  3  6  7  9 13 17 18 19 20 22 25 27 28 33 35 46 47 49 51 52 54 56
#  57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  3  6  8  9 12 15 16 19 20 22 23 25 28 30 33 34 47 49 50 51 52 54 55
#  56 57]
# Accuracy (partial): 0.9810578105781058
# ------------
# selected_features (partial): [ 0  1  3  5 12 13 16 18 19 20 22 26 28 30 31 33 34 35 37 38 47 50 51 52
#  57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 0  1  3  4  5 17 19 20 22 23 24 27 28 30 33 34 35 39 40 46 49 50 54 56
#  57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  3  4  7  8  9 12 13 16 17 18 19 20 22 24 26 27 28 31 33 34 35 36 37
#  39 44 47 49 50 52 54 56 57]
# Accuracy (partial): 0.9808118081180812
# ------------
# selected_features (partial): [ 0  1  3  5  6  9 15 16 17 18 19 22 26 27 33 34 35 39 41 44 46 47 50 51
#  54 56]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  3  5  6  8 17 18 19 20 23 24 26 29 30 33 37 39 40 42 45 46 49 50
#  54 56]
# Accuracy (partial): 0.9773677736777368
# ------------
# selected_features (partial): [ 0  1  3  5  6  8  9 12 13 18 19 22 23 25 26 27 35 39 44 45 47 49 51 52
#  56 57]
# Accuracy (partial): 0.9810578105781058
# ------------
# selected_features (partial): [ 1  2  3  4  9 13 16 17 18 22 23 25 26 27 31 33 35 37 39 40 41 46 47 52
#  54 56 57]
# Accuracy (partial): 0.9734317343173432
# ------------
# selected_features (partial): [ 0  1  3  5  6 10 12 16 17 18 20 24 25 26 27 32 33 34 35 37 39 45 46 47
#  51 52 54 56 57]
# Accuracy (partial): 0.9785977859778597
# ------------
# selected_features (partial): [ 0  1  3  4  7  9 12 17 18 19 20 22 24 27 28 33 40 41 46 47 49 51 52 56
#  57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  3  5  6  8  9 10 12 13 16 18 19 20 22 26 27 28 30 33 34 35 37 39
#  45 49 51 52 54 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  3  8  9 17 18 19 20 22 25 26 27 28 30 33 34 37 40 50 52 54 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  3  5  6  9 12 17 18 19 20 22 23 25 26 27 28 33 39 40 46 47 50 51
#  54 56 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  1  3  6  7 17 18 19 20 22 26 28 30 31 37 39 41 48 49 50 51 52 54 56
#  57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  3  5  8  9 17 18 20 22 27 28 30 45 46 49 50 54 56 57]
# Accuracy (partial): 0.9808118081180812
# ------------
# selected_features (partial): [ 1  3  5  6  8  9 17 19 20 24 28 30 31 33 34 39 44 49 52 54 55 56 57]
# Accuracy (partial): 0.9771217712177122
# ------------
# selected_features (partial): [ 1  3  4  5  6 12 16 17 19 20 22 23 24 25 27 28 33 34 39 45 46 47 49 50
#  51 54 56 57]
# Accuracy (partial): 0.9845018450184502
# ------------
# selected_features (partial): [ 1  3  5  7  9 13 17 18 19 22 24 25 26 28 30 32 33 34 37 47 51 52 57]
# Accuracy (partial): 0.9837638376383764
# ------------
# selected_features (partial): [ 0  1  3  4  9 12 13 16 17 18 19 20 26 27 28 30 33 34 35 37 39 40 41 47
#  51 52 54 55 56 57]
# Accuracy (partial): 0.980319803198032
# ------------
# selected_features (partial): [ 0  1  3  5  7  8  9 12 13 17 18 19 22 24 25 28 30 32 33 35 37 40 47 51
#  52 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  3  5  6  8  9 12 17 18 19 22 25 28 32 33 36 37 39 40 46 47 49 51
#  54 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  3  7  9 17 18 19 22 25 27 28 30 33 35 44 47 51 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  3  5  6  7 13 17 18 20 22 27 28 30 33 34 37 40 49 51 54 56 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  1  3  5  6  7  9 17 18 19 20 22 25 28 32 33 44 47 51 52 56 57]
# Accuracy (partial): 0.9835178351783518
# ------------
# selected_features (partial): [ 0  1  3  5 13 17 18 19 20 22 25 28 35 40 46 47 49 51 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  5  9 13 17 18 22 25 28 33 37 39 40 46 51 52 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  3  5  9 12 13 17 18 19 20 22 23 25 26 27 28 30 33 35 40 46 47 49 51
#  52 56 57]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 0  1  3  5  7  9 17 19 20 22 23 25 26 27 28 30 32 33 35 37 39 46 47 49
#  51 52 54 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 0  3  5  6  9 12 13 18 19 20 22 23 26 28 30 33 34 35 40 46 47 51 54 56
#  57]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 1  3  5  6  7  8 17 18 20 22 27 28 30 33 39 40 44 51 54 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  3  7 13 17 18 22 25 28 30 33 34 35 37 39 40 51 52 54 56 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  3  5  7  9 17 20 22 25 28 33 34 44 47 49 51 52 54 56 57]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 0  1  5  6  7  9 17 18 22 25 28 30 33 37 47 51 52 54 56]
# Accuracy (partial): 0.9842558425584256
# ------------
# selected_features (partial): [ 0  1  3  5  9 18 19 20 22 25 28 32 33 40 44 49 51 52 54 56 57]
# Accuracy (partial): 0.9800738007380074
# ------------
# selected_features (partial): [ 1  6  9 13 17 18 20 22 25 27 28 30 33 34 39 42 47 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  3  5  6  9 17 18 19 20 22 25 28 32 33 40 44 46 49 51 52 54 56 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  1  7 17 18 22 25 27 28 32 33 47 51 54 56 57]
# Accuracy (partial): 0.9835178351783518
# ------------
# selected_features (partial): [ 0  1  5  7  9 17 18 19 20 22 25 28 33 35 37 47 51 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  5  7  9 18 19 20 22 25 27 28 30 33 34 37 47 51 54 56 57]
# Accuracy (partial): 0.9808118081180812
# ------------
# selected_features (partial): [ 1  5  7  9 13 17 18 20 22 25 27 28 30 33 34 39 51 52 54 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  3  7  9 13 17 18 22 25 27 28 33 34 37 39 51 52 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7  9 12 13 17 18 22 28 30 33 34 39 51 52 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 0  1  3  6  7 13 17 18 22 27 28 34 37 39 47 51 52 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  6  7  9 13 17 18 20 22 25 26 27 33 35 39 51 52 54 56]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 0  1  7  9 12 13 17 18 20 25 32 33 34 37 40 51 52 54 56 57]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 1  3  9 13 17 19 20 25 28 30 33 34 35 37 47 51 56 57]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 0  1  3  7 13 17 18 20 22 28 32 33 34 37 47 52 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 0  1  3  7 17 18 20 25 28 33 34 44 47 48 51 52 54]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  1  7 13 17 18 20 22 25 27 28 30 33 34 35 39 51 52 54 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 0  1  7 17 18 28 33 51 52 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  7 17 18 20 22 26 28 30 32 33 34 39 47 51 52 54 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  7 17 18 20 22 25 27 28 32 33 34 37 40 44 47 49 51 54 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 0  1  7 17 18 22 25 28 32 33 44 47 48 51 56]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  7 17 18 20 25 33 34 47 51 52 54 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  3  7  9 17 18 25 28 32 33 34 37 44 48 51 52 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7 17 18 22 25 28 32 33 35 37 40 51 52 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 0  1  7 13 18 25 28 32 33 51 52 56 57]
# Accuracy (partial): 0.9800738007380074
# ------------
# selected_features (partial): [ 1  7 17 18 22 25 27 28 33 48 51 54 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 0  1  7 17 18 20 22 25 27 28 32 33 39 47 48 51 52 54 56 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 1  7 12 18 20 22 25 28 32 33 47 48 51 52 56 57]
# Accuracy (partial): 0.9808118081180812
# ------------
# selected_features (partial): [ 1  7 17 18 25 28 33 35 39 44 47 48 51 52 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7 17 18 22 25 28 32 33 35 37 44 47 49 51 52 54 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 20 22 25 26 28 33 44 47 49 51 52 54 56 57]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 0  1  7 17 18 22 25 28 30 32 33 47 48 51 52 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  7 18 20 22 25 28 47 48 51 52 54 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 0  7 17 18 22 28 32 33 44 47 48 51 52 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  7 17 18 26 33 44 48 51 54 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 17 18 20 22 26 30 33 44 48 51 52 54 56 57]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 1  7 17 18 25 28 33 44 49 51 52 54 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 0  1  7 17 18 20 22 25 28 33 44 49 52 54 57]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 1  7 17 18 22 25 28 33 44 48 51 54 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7 17 18 20 22 25 28 33 51 52 54 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 0  1  7 17 18 27 28 33 49 51 52 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7 17 18 22 25 28 33 51 52 54 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7 17 18 28 51 52 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7 17 18 28 32 33 44 48 51 52 54 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 1  5  7 18 22 28 44 49 51 52 54 56 57]
# Accuracy (partial): 0.9810578105781058
# ------------
# selected_features (partial): [ 1  7 17 18 28 33 44 49 51 52 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 0  1  7 12 17 18 22 28 33 44 51 52 54 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 1  7  9 17 18 25 28 33 44 51 54 56]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 1  7 17 18 20 28 33 44 51 52 54 56]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 1  3  7 17 18 28 33 44 49 51 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  3  7 17 18 28 32 33 51 54 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 17 18 27 28 33 39 44 49 51 52 54 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 1 17 18 22 25 28 33 44 51 52 56]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 1  7 17 18 28 33 44 51 52 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 17 18 20 22 27 28 33 44 51 54 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 1  7 17 18 25 27 28 44 49 51 52 54 56 57]
# Accuracy (partial): 0.9835178351783518
# ------------
# selected_features (partial): [ 0  4  7 12 17 18 22 25 28 33 39 44 49 51 52 54 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 7 17 18 28 33 51 52 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 17 18 22 28 33 44 51 56]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 1  7 17 18 22 25 28 33 39 44 51 52 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  7 17 18 20 25 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  3  7 17 18 25 28 33 51 52 56 57]
# Accuracy (partial): 0.9835178351783518
# ------------
# selected_features (partial): [ 0  1  3  7 17 18 20 28 33 51 52 54 56]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 1  7 17 18 22 25 28 33 44 49 51 56]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 1 17 18 20 28 33 39 44 49 51 52 56]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 7 17 18 25 28 33 51 56]
# Accuracy (partial): 0.9835178351783518
# ------------
# selected_features (partial): [ 1  7 17 18 26 27 28 33 51 52 56]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 1  7 17 18 22 28 33 51 56]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 1  7 17 18 22 28 33 51 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 1  7 18 22 28 33 51 56]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 1  7 17 18 22 28 33 49 51 56]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 1 17 18 25 28 33 44 49 51 52 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 17 18 20 22 25 28 33 51 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 1  4  7 17 18 22 25 28 33 39 44 51 52 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  7 17 18 22 25 28 33 44 51 54 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 7 17 18 26 28 33 44 51 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 18 20 22 28 51 54 56 57]
# Accuracy (partial): 0.9822878228782288
# ------------
# selected_features (partial): [ 1  7 17 18 25 27 28 33 51 52 56 57]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 1 18 22 28 33 51 52 56 57]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 0  1  7 17 18 22 28 33 44 51 54 56]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 1  7 18 22 28 33 49 51 54 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 1  7 17 18 22 28 33 44 51 56 57]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 1  3  7 18 22 25 28 33 51 54 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 17 18 22 28 33 51 56 57]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 7 17 18 28 44 51 52 56 57]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 1  7 18 22 28 33 44 49 51 56]
# Accuracy (partial): 0.981549815498155
# ------------
# selected_features (partial): [ 1  4  7 17 18 22 26 28 33 51 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 7 17 18 22 28 33 44 51 56]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 1 17 18 22 28 33 51 56]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 7 17 18 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 17 18 25 28 33 51 56]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 1  7 10 18 25 28 33 44 51 52 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 17 18 28 33 44 51 52 56 57]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 18 28 33 51 56]
# Accuracy (partial): 0.9832718327183272
# ------------
# selected_features (partial): [ 7 17 18 22 28 33 51 56 57]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 7 10 17 18 28 33 35 51 52 56]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 7 17 18 22 28 33 44 51 56 57]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 1 17 18 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 7 17 18 25 28 33 51 56 57]
# Accuracy (partial): 0.9835178351783518
# ------------
# selected_features (partial): [ 1  7 17 18 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 18 22 28 49 51 56]
# Accuracy (partial): 0.9810578105781058
# ------------
# selected_features (partial): [ 1 18 28 51 56]
# Accuracy (partial): 0.982779827798278
# ------------
# selected_features (partial): [ 1 17 18 22 28 33 44 51 56]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 1 18 22 28 33 51 56 57]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 1 10 18 22 28 33 51 56]
# Accuracy (partial): 0.9817958179581796
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1  7 17 18 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 17 18 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1  7 18 22 25 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 17 18 28 33 51 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 25 28 33 51 52 56]
# Accuracy (partial): 0.9825338253382534
# ------------
# selected_features (partial): [ 1 18 20 28 33 51 56 57]
# Accuracy (partial): 0.9813038130381304
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 22 28 33 51 56]
# Accuracy (partial): 0.9820418204182042
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56 57]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# selected_features (partial): [ 1 18 28 33 51 56]
# Accuracy (partial): 0.9830258302583026
# ------------
# Completed in 161.88068962097168
# selected_features (final): 5 [ 1 18 28 51 56]
# accuracy_score (final): 0.982779827798278
